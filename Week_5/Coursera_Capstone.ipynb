# %% [markdown]
# # Coursera Capstone

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# %%
website_url = "https://en.wikipedia.org/wiki/List_of_colleges_and_universities_in_Rhode_Island"

# %%
universities = pd.read_html(website_url,header =0, flavor='bs4', )[0]

# %%
universities
# Out:
#                                  School  Location(s)[2]     Affiliation[2]  \
# 0                      Brown University      Providence            Private
# 1                     Bryant University      Smithfield            Private
# 2     Community College of Rhode Island     6 locations             Public
# 3            Johnson & Wales University      Providence            Private
# 4                     Naval War College         Newport    Public(Federal)
# 5   New England Institute of Technology  East Greenwich            Private
# 6                    Providence College      Providence  Private(Catholic)
# 7                  Rhode Island College      Providence             Public
# 8         Rhode Island School of Design      Providence            Private
# 9             Roger Williams University         Bristol            Private
# 10              Salve Regina University         Newport  Private(Catholic)
# ...

# %%
universities.rename(columns={'Location(s)[2]':'Location','Affiliation[2]':'Affiliation'},inplace=True)
universities.rename(columns={'Type[2][a]':'Type','Enrollment[b](2016)':'Enrollment(2016)'},inplace=True)

# %%
Providence_universities = universities[universities.Location=='Providence']
Providence_universities
# Out:
#                           School    Location        Affiliation  \
# 0               Brown University  Providence            Private
# 3     Johnson & Wales University  Providence            Private
# 6             Providence College  Providence  Private(Catholic)
# 7           Rhode Island College  Providence             Public
# 8  Rhode Island School of Design  Providence            Private
#
#                   Type Enrollment(2016)   Founded
# 0  Doctoral university             9781   1764[3]
# 3  Master's university         9,324[c]   1914[6]
# 6  Master's university             4568  1917[10]
# 7  Master's university             8446  1854[11]
# 8        School of art             2477  1877[12]

# %%
#!conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

#!conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

# %%
CLIENT_ID = '5LMC2BTAOAZAUOWXLVSNB4O3012A4CSCINFW031DMIQMUAJ4' 
CLIENT_SECRET = '5CCCJ5A1FVJXFERY0HM3OQQCHPSVDN31MHIU0V1ONLX3SZ5O' 
VERSION = '20180604'
LIMIT = 1000
radius=400000
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 5LMC2BTAOAZAUOWXLVSNB4O3012A4CSCINFW031DMIQMUAJ4
# CLIENT_SECRET:5CCCJ5A1FVJXFERY0HM3OQQCHPSVDN31MHIU0V1ONLX3SZ5O

# %%
address = 'Providence, Rhode Island'

geolocator = Nominatim(user_agent="coursera_project")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 41.8239891 -71.4128343

# %%
search_query = 'coffee'

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=5LMC2BTAOAZAUOWXLVSNB4O3012A4CSCINFW031DMIQMUAJ4&client_secret=5CCCJ5A1FVJXFERY0HM3OQQCHPSVDN31MHIU0V1ONLX3SZ5O&ll=41.8239891,-71.4128343&v=20180604&query=coffee&radius=400000&limit=1000'

# %%
results = requests.get(url).json()

# %%
# make the GET request
results = requests.get(url).json()["response"]

# %%
venue_list = results['venues']

# %%
print(type(venue_list))
print(type(venue_list[0]))
# Out:
# <class 'list'>
# <class 'dict'>

# %%
# first element in the venue_list
venue_list[0]
# Out:
# {'id': '5cee699460255e002ca54014',
#  'name': 'Poindexter Coffee',
#  'location': {'address': '5 Dorrance St',
#   'lat': 41.82475,
#   'lng': -71.413634,
#   'labeledLatLngs': [{'label': 'display', 'lat': 41.82475, 'lng': -71.413634}],
#   'distance': 107,
#   'postalCode': '02903',
#   'cc': 'US',
#   'neighborhood': 'Downtown Providence',
#   'city': 'Providence',
#   'state': 'RI',
#   'country': 'United States',
#   'formattedAddress': ['5 Dorrance St',
#    'Providence, RI 02903',
#    'United States']},
#  'categories': [{'id': '4bf58dd8d48988d1e0931735',
#    'name': 'Coffee Shop',
#    'pluralName': 'Coffee Shops',
#    'shortName': 'Coffee Shop',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#     'suffix': '.png'},
#    'primary': True}],
#  'referralId': 'v-1589138022',
#  'hasPerk': False}

# %%
venue_list[0].get("name")
# Out:
# 'Poindexter Coffee'

# %%
# Coffee shop list

for i in venue_list:
    print(i.get("name"))
# Out:
# Poindexter Coffee
# Bolt Coffee Company
# Lou's Coffee Plus
# Bolt Coffee
# Bolt Coffee
# Blue State Coffee (Brown Bookstore)
# New Harvest Coffee & Spirits
# Dave's Coffee
# Coffee Plus Snack Bar
# The Coffee Exchange
# The Coffee Station
# Bolt Coffee at the RISD Museum
# Coffee Plus Snack Bar
# Henri-Annes Coffee Cafe
# Mills Coffee Roasting Co.
# White Electric Coffee
# Coffee Bean Express
# Haru Coffee
# Carpentola Coffee Lab
# Providence Coffee Roasters
# Blue State Coffee
# Vanuatu Coffee Roasters
# Bolt Coffee Roastery
# white horse wine and coffee
# Seattle's Best Coffee
# Bob's Coffee Plus
# Marylou's Coffee
# The Coffee Grinder 2.0
# New Harvest Coffee Roasters
# Green Mountain Coffee Express and Café at RWU College of Arts and Science
# Thriving Coffee House
# The Pink Bean Coffee
# Marylou's Coffee
# Empire Tea & Coffee
# Supreme Coffee & Donuts
# Marylou's Coffee
# Red Barn Coffee At Angel's Cafe
# Better Bean Coffee Co
# Dave's Coffee
# Coffee Break Cafe
# ...

# %%
venue_df = json_normalize(venue_list)

# %%
venue_df.head(3)
# Out:
#                                           categories delivery.id  \
# 0  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...         NaN
# 1  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...         NaN
# 2  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...         NaN
#
#   delivery.provider.icon.name delivery.provider.icon.prefix  \
# 0                         NaN                           NaN
# 1                         NaN                           NaN
# 2                         NaN                           NaN
#
#   delivery.provider.icon.sizes delivery.provider.name delivery.url  hasPerk  \
# 0                          NaN                    NaN          NaN    False
# 1                          NaN                    NaN          NaN    False
# 2                          NaN                    NaN          NaN    False
#
#                          id    location.address  ...  \
# 0  5cee699460255e002ca54014       5 Dorrance St  ...
# ...

# %%
venue_df.columns
# Out:
# Index(['categories', 'delivery.id', 'delivery.provider.icon.name',
#        'delivery.provider.icon.prefix', 'delivery.provider.icon.sizes',
#        'delivery.provider.name', 'delivery.url', 'hasPerk', 'id',
#        'location.address', 'location.cc', 'location.city', 'location.country',
#        'location.crossStreet', 'location.distance',
#        'location.formattedAddress', 'location.labeledLatLngs', 'location.lat',
#        'location.lng', 'location.neighborhood', 'location.postalCode',
#        'location.state', 'name', 'referralId', 'venuePage.id'],
#       dtype='object')

# %%
venue_df1 = venue_df[['name','categories','location.address','location.lat',
       'location.lng', 'location.neighborhood','location.state']]
venue_df1.head(3)
# Out:
#                   name                                         categories  \
# 0    Poindexter Coffee  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...
# 1  Bolt Coffee Company  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...
# 2    Lou's Coffee Plus  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...
#
#      location.address  location.lat  location.lng location.neighborhood  \
# 0       5 Dorrance St     41.824750    -71.413634   Downtown Providence
# 1     122 Fountain St     41.823184    -71.416009   Downtown Providence
# 2  380 Westminster St     41.821190    -71.414633                   NaN
#
#   location.state
# 0             RI
# 1             RI
# 2             RI

# %%
venue_category_series = venue_df1['categories']

liste= []

for i in range(len(venue_category_series)):
    liste.append(venue_category_series[0][0])

# %%
for i in liste:
    print(i.get("name"))
# Out:
# Coffee Shop
# Coffee Shop
# Coffee Shop
# Coffee Shop
# Coffee Shop
# Coffee Shop
# Coffee Shop
# Coffee Shop
# Coffee Shop
# Coffee Shop
# Coffee Shop
# Coffee Shop
# Coffee Shop
# Coffee Shop
# Coffee Shop
# Coffee Shop
# Coffee Shop
# Coffee Shop
# Coffee Shop
# Coffee Shop
# Coffee Shop
# Coffee Shop
# Coffee Shop
# Coffee Shop
# Coffee Shop
# Coffee Shop
# Coffee Shop
# Coffee Shop
# Coffee Shop
# Coffee Shop
# Coffee Shop
# Coffee Shop
# Coffee Shop
# Coffee Shop
# Coffee Shop
# Coffee Shop
# Coffee Shop
# Coffee Shop
# Coffee Shop
# Coffee Shop
# Coffee Shop
# Coffee Shop
# Coffee Shop
# Coffee Shop
# Coffee Shop
# Coffee Shop
# Coffee Shop
# Coffee Shop
# Coffee Shop
# Coffee Shop

# %%
venue_df1['category'] = 'Coffee Shop'
venue_df1 = venue_df1.drop(columns='categories')
venue_df1.head()
# Out:
# /Users/Murat/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                   name    location.address  location.lat  location.lng  \
# 0    Poindexter Coffee       5 Dorrance St     41.824750    -71.413634
# 1  Bolt Coffee Company     122 Fountain St     41.823184    -71.416009
# 2    Lou's Coffee Plus  380 Westminster St     41.821190    -71.414633
# 3          Bolt Coffee         225 Dyer St     41.820457    -71.408310
# 4          Bolt Coffee    61 Washington St     41.823952    -71.413622
#
#   location.neighborhood location.state     category
# 0   Downtown Providence             RI  Coffee Shop
# ...

# %%
venue_df1.rename(columns={'location.address':'address','location.lat':'lat','location.lng':'lng'},inplace=True)
venue_df1.rename(columns={'location.neighborhood':'neighborhood','location.state':'state'},inplace=True)
venue_df1.columns
# Out:
# Index(['name', 'address', 'lat', 'lng', 'neighborhood', 'state', 'category'], dtype='object')

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) 

# add a red circle marker to represent the Providence
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Providence',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Coffee Shops as blue circle markers

for lat, lng, label in zip(venue_df1.lat, venue_df1.lng, venue_df1.category):
    
    folium.CircleMarker([lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
search_query = 'University'

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=5LMC2BTAOAZAUOWXLVSNB4O3012A4CSCINFW031DMIQMUAJ4&client_secret=5CCCJ5A1FVJXFERY0HM3OQQCHPSVDN31MHIU0V1ONLX3SZ5O&ll=41.8239891,-71.4128343&v=20180604&query=University&radius=400000&limit=1000'

# %%
#results_uni

# %%
# make the GET request

results_uni = requests.get(url).json()["response"]

# %%
uni_venue_list = results_uni['venues']

# %%
# Univerisy list

for i in uni_venue_list:
    print(i.get("name"))
# Out:
# Brown University
# The University of Rhode Island Feinstein Providence Campus
# University Heights Apartments
# Brown University School of Professional Studies
# University Orthopedics
# University Pasta Place JWU
# University Piercing and Tattoo
# University Mart
# University Otolaryngology Head & Neck Surgery, Inc.
# University Help Desk
# University OB-GYN, INC.
# University Club
# University Market Place
# Roger Williams University
# Johnson & Wales University
# Brown University School of Public Health
# University Hall
# University Heights
# University Medicine Foundation
# Roger Williams University - Providence Campus
# Brown University Center for Alcohol & Addiction Studies
# Johnson & Wales University - Downtown Campus Bookstore
# Brown University School of Public Health
# John Carter Brown Library - Brown University
# Harkness House Brown University
# University Orthopedics
# Brown University South Main
# Piezoni's (Near Brown University)
# Brown University Medical Building
# ...

# %%
uni_df = json_normalize(uni_venue_list)

# %%
uni_df.head(3)
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1ae941735', 'name': 'U...    False
# 1  [{'id': '4bf58dd8d48988d1a8941735', 'name': 'G...    False
# 2  [{'id': '4d954b06a243a5684965b473', 'name': 'R...    False
#
#                          id        location.address location.cc location.city  \
# 0  4ac654caf964a520c6b320e3           1 Prospect St          US    Providence
# 1  4b7572acf964a5200b0d2ee3        80 Washington St          US    Providence
# 2  4bc26ca9f8219c749de7b410  99 Roger Williams Gree          US    Providence
#
#   location.country location.crossStreet  location.distance  \
# 0    United States                  NaN                718
# 1    United States            Union St.                117
# 2    United States                  NaN               1409
#
#                            location.formattedAddress  \
# 0  [1 Prospect St, Providence, RI 02912, United S...
# ...

# %%
uni_df.columns
# Out:
# Index(['categories', 'hasPerk', 'id', 'location.address', 'location.cc',
#        'location.city', 'location.country', 'location.crossStreet',
#        'location.distance', 'location.formattedAddress',
#        'location.labeledLatLngs', 'location.lat', 'location.lng',
#        'location.postalCode', 'location.state', 'name', 'referralId',
#        'venuePage.id'],
#       dtype='object')

# %%
uni_df1 = uni_df[['name','categories','location.address','location.lat',
       'location.lng','location.state','location.city']]

uni_df1.rename(columns={'location.address':'address','location.lat':'lat','location.lng':'lng'},inplace=True)
uni_df1.rename(columns={'location.state':'state','location.city':'city'},inplace=True)

uni_df1.head(3)
# Out:
#                                                 name  \
# 0                                   Brown University
# 1  The University of Rhode Island Feinstein Provi...
# 2                      University Heights Apartments
#
#                                           categories                 address  \
# 0  [{'id': '4bf58dd8d48988d1ae941735', 'name': 'U...           1 Prospect St
# 1  [{'id': '4bf58dd8d48988d1a8941735', 'name': 'G...        80 Washington St
# 2  [{'id': '4d954b06a243a5684965b473', 'name': 'R...  99 Roger Williams Gree
#
#          lat        lng state        city
# 0  41.826148 -71.404674    RI  Providence
# 1  41.823345 -71.413960    RI  Providence
# 2  41.835978 -71.407368    RI  Providence

# %%
uni_df1.shape[0]
# Out:
# 50

# %%
liste_1 = []

for i in range(uni_df1.shape[0]):
     
    liste_1.append(uni_df1.categories[i][0].get("name"))
    
uni_df1['category'] = liste_1
# Out:
# /Users/Murat/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
uni_df1 = uni_df1.drop(columns='categories')

# %%
uni_df1
# Out:
#                                                  name  \
# 0                                    Brown University
# 1   The University of Rhode Island Feinstein Provi...
# 2                       University Heights Apartments
# 3     Brown University School of Professional Studies
# 4                              University Orthopedics
# 5                          University Pasta Place JWU
# 6                      University Piercing and Tattoo
# 7                                     University Mart
# 8   University Otolaryngology Head & Neck Surgery,...
# 9                                University Help Desk
# 10                            University OB-GYN, INC.
# 11                                    University Club
# 12                            University Market Place
# 13                          Roger Williams University
# 14                         Johnson & Wales University
# 15           Brown University School of Public Health
# ...

# %%
uni_df1.category.value_counts()
# Out:
# Doctor's Office                             6
# University                                  6
# College Academic Building                   5
# College Administrative Building             5
# College Library                             2
# College Lab                                 2
# Restaurant                                  1
# Student Center                              1
# Italian Restaurant                          1
# Pizza Place                                 1
# Farmers Market                              1
# Tattoo Parlor                               1
# Professional & Other Places                 1
# College Technology Building                 1
# Spiritual Center                            1
# College Rec Center                          1
# General College & University                1
# Miscellaneous Shop                          1
# College Bookstore                           1
# Neighborhood                                1
# ...

# %%
uni_df2 = uni_df1[uni_df1.category=='University']
uni_df2
# Out:
#                                         name           address        lat  \
# 0                           Brown University     1 Prospect St  41.826148
# 9                       University Help Desk  Weybosset Street  41.821487
# 13                 Roger Williams University               NaN  41.822758
# 14                Johnson & Wales University  8 Abbott Park Pl  41.820007
# 22  Brown University School of Public Health               NaN  41.824212
# 44      Brown University Geological Sciences               NaN  41.826154
#
#           lng         state        city    category
# 0  -71.404674            RI  Providence  University
# 9  -71.408392            RI  Providence  University
# 13 -71.415238  Rhode Island         NaN  University
# 14 -71.412785            RI  Providence  University
# 22 -71.407054            RI  Providence  University
# 44 -71.400479            RI  Providence  University

# %%
uni_df3 = uni_df2.iloc[[0,2,3],:]
uni_df3
# Out:
#                           name           address        lat        lng  \
# 0             Brown University     1 Prospect St  41.826148 -71.404674
# 13   Roger Williams University               NaN  41.822758 -71.415238
# 14  Johnson & Wales University  8 Abbott Park Pl  41.820007 -71.412785
#
#            state        city    category
# 0             RI  Providence  University
# 13  Rhode Island         NaN  University
# 14            RI  Providence  University

# %%
search_query = 'Providence College'

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url

results_uni_PC = requests.get(url).json()

# %%
# make the GET request

results_uni_PC = requests.get(url).json()["response"]

# %%
results_uni_PC_df = json_normalize(results_uni_PC_list)

# %%
results_uni_PC_df.iloc[0,:]
# Out:
# categories                       [{'id': '4bf58dd8d48988d1ae941735', 'name': 'U...
# delivery.id                                                                    NaN
# delivery.provider.icon.name                                                    NaN
# delivery.provider.icon.prefix                                                  NaN
# delivery.provider.icon.sizes                                                   NaN
# delivery.provider.name                                                         NaN
# delivery.url                                                                   NaN
# hasPerk                                                                      False
# id                                                        4b0586acf964a520ae6922e3
# location.address                                                   1 Cunningham Sq
# location.cc                                                                     US
# ...

# %%
Providence_universities
# Out:
#                           School    Location        Affiliation  \
# 0               Brown University  Providence            Private
# 3     Johnson & Wales University  Providence            Private
# 6             Providence College  Providence  Private(Catholic)
# 7           Rhode Island College  Providence             Public
# 8  Rhode Island School of Design  Providence            Private
#
#                   Type Enrollment(2016)   Founded
# 0  Doctoral university             9781   1764[3]
# 3  Master's university         9,324[c]   1914[6]
# 6  Master's university             4568  1917[10]
# 7  Master's university             8446  1854[11]
# 8        School of art             2477  1877[12]

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) 

# add a red circle marker to represent the Providence
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Providence',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# display map
venues_map

# add the Coffee Shops as blue circle markers

for lat, lng, label in zip(uni_df1.lat, uni_df1.lng, uni_df1.category):
    
    folium.CircleMarker([lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
#venues_map
